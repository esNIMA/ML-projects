# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set the random seed
np.random.seed(42)
imgList= []
rand = np.random.randint(1 , 36 , size = 3)
rand
# Out:
# array([29, 15,  8])

# %% [markdown]
# ## Loading the images

# %%
# Read the image
img1 = cv.imread(f'Dataset_02/{rand[0]}.png')

# Check if the image is successfully loaded
if img1 is None:
    print("Error: Unable to read the image.")
else:
    print("Image successfully loaded.")
# Out:
# Image successfully loaded.

# %%
# Read the image
img2 = cv.imread(f'Dataset_02/{rand[1]}.png')

# Check if the image is successfully loaded
if img2 is None:
    print("Error: Unable to read the image.")
else:
    print("Image successfully loaded.")
# Out:
# Image successfully loaded.

# %%
# Read the image
img3 = cv.imread(f'Dataset_02/{rand[2]}.png')

# Check if the image is successfully loaded
if img3 is None:
    print("Error: Unable to read the image.")
else:
    print("Image successfully loaded.")
# Out:
# Image successfully loaded.

# %% [markdown]
# ## Showing each image and its dimension

# %%
# Convert the image from BGR to RGB format
img1_rgb = cv.cvtColor(img1, cv.COLOR_BGR2RGB)
# Display the image using matplotlib
plt.imshow(img1_rgb)
plt.axis('off')  # Hide axis
plt.show()

# %%
# Get the dimensions of the image
height, width, channels = img1.shape

print(f"Height: {height}, Width: {width}, Channels: {channels}")
# Out:
# Height: 60, Width: 64, Channels: 3

# %%
# Convert the image from BGR to RGB format
img2_rgb = cv.cvtColor(img2, cv.COLOR_BGR2RGB)
# Display the image using matplotlib
plt.imshow(img2_rgb)
plt.axis('off')  # Hide axis
plt.show()

# %%
# Get the dimensions of the image
height, width, channels = img2.shape

print(f"Height: {height}, Width: {width}, Channels: {channels}")
# Out:
# Height: 77, Width: 76, Channels: 3

# %%
# Convert the image from BGR to RGB format
img3_rgb = cv.cvtColor(img3, cv.COLOR_BGR2RGB)
# Display the image using matplotlib
plt.imshow(img3_rgb)
plt.axis('off')  # Hide axis
plt.show()

# %%
# Get the dimensions of the image
height, width, channels = img3.shape

print(f"Height: {height}, Width: {width}, Channels: {channels}")
# Out:
# Height: 89, Width: 77, Channels: 3

# %% [markdown]
# ## Gray scale convertion

# %% [markdown]
# ### First image

# %%
# Convert the image to grayscale
gray_img1 = cv.cvtColor(img1_rgb, cv.COLOR_BGR2GRAY)
# Display the grayscale image
plt.imshow(gray_img1)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ### Second image

# %%
# Convert the image to grayscale
gray_img2 = cv.cvtColor(img2_rgb, cv.COLOR_BGR2GRAY)
# Display the grayscale image
plt.imshow(gray_img2)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ### Third image

# %%
# Convert the image to grayscale
gray_img3 = cv.cvtColor(img3_rgb, cv.COLOR_BGR2GRAY)
# Display the grayscale image
plt.imshow(gray_img3)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ## Adjusting image brightness and contrast

# %%
def adjust_brightness_contrast_gray(img, alpha=1.0, beta=0):
    # Apply brightness and contrast adjustment to the image
    adjusted_img = np.clip(alpha * img + beta, 0, 255).astype(np.uint8)
    return adjusted_img

# %% [markdown]
# ## Image 1

# %%
adj_img1 = adjust_brightness_contrast_gray(gray_img1, alpha=0.5, beta=-30)
plt.imshow(adj_img1)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ## Image 2

# %%
adj_img2 = adjust_brightness_contrast_gray(gray_img2, alpha=1.5, beta=-70)
plt.imshow(adj_img2)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ## Image 3

# %%
adj_img3 = adjust_brightness_contrast_gray(gray_img3, alpha=1.5, beta=-50)
plt.imshow(adj_img3)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ## Normalizing the images

# %%
def normalize_image(image):
    # Convert image to floating point format
    normalized_image = image.astype('float32')
    
    # Normalize pixel values to the range [0, 1]
    normalized_image /= 255.0
    
    return normalized_image

# %%
# Normalize the image
normalized_img1 = normalize_image(gray_img1)

# %%
plt.imshow(normalized_img1)
plt.axis('off')  # Hide axis
plt.show()

# %%
# Normalize the image
normalized_img2 = normalize_image(gray_img2)
plt.imshow(normalized_img2)
plt.axis('off')  # Hide axis
plt.show()

# %%
# Normalize the image
normalized_img3 = normalize_image(gray_img3)
plt.imshow(normalized_img3)
plt.axis('off')  # Hide axis
plt.show()
